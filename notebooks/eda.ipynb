# %%
import pandas as pd

# %%
data = pd.read_csv("../data/raw/Base.csv")

# %%
data.describe().round(1).T
# Out:
#                                       count    mean     std     min     25%  \
# fraud_bool                        1000000.0     0.0     0.1     0.0     0.0
# income                            1000000.0     0.6     0.3     0.1     0.3
# name_email_similarity             1000000.0     0.5     0.3     0.0     0.2
# prev_address_months_count         1000000.0    16.7    44.0    -1.0    -1.0
# current_address_months_count      1000000.0    86.6    88.4    -1.0    19.0
# customer_age                      1000000.0    33.7    12.0    10.0    20.0
# days_since_request                1000000.0     1.0     5.4     0.0     0.0
# intended_balcon_amount            1000000.0     8.7    20.2   -15.5    -1.2
# zip_count_4w                      1000000.0  1572.7  1005.4     1.0   894.0
# velocity_6h                       1000000.0  5665.3  3009.4  -170.6  3436.4
# velocity_24h                      1000000.0  4769.8  1479.2  1300.3  3593.2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 32 columns):
#  #   Column                            Non-Null Count    Dtype
# ---  ------                            --------------    -----
#  0   fraud_bool                        1000000 non-null  int64
#  1   income                            1000000 non-null  float64
#  2   name_email_similarity             1000000 non-null  float64
#  3   prev_address_months_count         1000000 non-null  int64
#  4   current_address_months_count      1000000 non-null  int64
#  5   customer_age                      1000000 non-null  int64
#  6   days_since_request                1000000 non-null  float64
#  7   intended_balcon_amount            1000000 non-null  float64
#  8   payment_type                      1000000 non-null  object
#  9   zip_count_4w                      1000000 non-null  int64
#  10  velocity_6h                       1000000 non-null  float64
# ...

# %%
data.head().round(2).T
# Out:
#                                          0         1         2         3  \
# fraud_bool                               0         0         0         0
# income                                 0.3       0.8       0.8       0.6
# name_email_similarity                 0.99      0.62       1.0      0.48
# prev_address_months_count               -1        -1         9        11
# current_address_months_count            25        89        14        14
# customer_age                            40        20        40        30
# days_since_request                    0.01      0.01      0.01      0.01
# intended_balcon_amount              102.45     -0.85     -1.49     -1.86
# payment_type                            AA        AD        AB        AB
# zip_count_4w                          1059      1658      1095      3483
# velocity_6h                       13096.04   9223.28   4471.47  14431.99
# velocity_24h                       7850.96   5745.25   5471.99   6755.34
# ...

# %%
data.select_dtypes(object).nunique()
# Out:
# payment_type         5
# employment_status    7
# housing_status       7
# source               2
# device_os            5
# dtype: int64
